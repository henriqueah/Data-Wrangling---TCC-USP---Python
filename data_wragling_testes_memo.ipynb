# %%
import pandas as pd
df = pd.read_excel("LOA_PPA_PLOA_detalhada.xlsx")
df.head(3)
# Out:
#   SKU REF. PROJETO LEI ORGAO ORCAMENTARIO  \
# 0     PLOA  PL 32/2022    Governo Federal
# 1     PLOA  PL 19/2021    Governo Federal
# 2     PLOA  PL 28/2020    Governo Federal
#
#                                               TITULO  \
# 0  Receita dos Orçamentos Fiscal e da Seguridade ...
# 1  Receita dos Orçamentos Fiscal e da Seguridade ...
# 2  Receita dos Orçamentos Fiscal e da Seguridade ...
#
#                                                FONTE EXERCICIO FINANCEIRO  \
# 0  Orcamento da Uniao – Exercicio financeiro de 2...           2023-01-01
# 1  Orcamento da Uniao – Exercicio financeiro de 2...           2022-01-01
# 2  Orcamento da Uniao – Exercicio financeiro de 2...           2021-01-01
#
#    RECEITAS CORRENTES  RECEITAS DE CAPITAL  \
# 0       2365991535840         655123274758
# 1       2071225586271         663581737135
# 2       1629164611312         914893992129
#
#    REFINANCIAMENTO DA DIVIDA PUBLICA FEDERAL  SOMA RECEITAS  DESPESA TOTAL
# 0                              2010264256580  3021114810598  5031379067178
# 1                              1884865486134  2734807323406  4619672809540
# 2                              1603521711208  2544058603441  4147580314649

# %%
# Ler o Excel com Pandas
df_xlsx = pd.ExcelFile("LOA_PPA_PLOA_detalhada.xlsx")

# Iterar por cada aba e salvar como CSV
for aba in df_xlsx.sheet_names:
    df = pd.read_excel(df_xlsx, aba)
    # Criar um nome de arquivo CSV baseado no nome da aba
    nome_arquivo_csv = f"{aba}.csv"
    df.to_csv(nome_arquivo_csv, index=False)  # index=False para não incluir o índice do DataFrame no CSV

# %%
# carregamento do dataset para entendimento
import time
start_time = time.time()
f_receita_orc_md = pd.read_csv(r'Receitas_Un.Orcam_MD_AnexoI.csv')
end_time = time.time()
elapsed_time = end_time - start_time
print(f"O código levou {elapsed_time} segundos para executar")
display(f_receita_orc_md)
#f_receita_orc_md.tail()
# Out:
# O código levou 0.01600170135498047 segundos para executar
#     SKU REF.           FA    SKU  \
# 0        LOA       DEFESA  52000
# 1        LOA       DEFESA  52101
# 2        LOA  AERONAUTICA  52111
# 3        LOA     EXERCITO  52121
# 4        LOA      MARINHA  52131
# ..       ...          ...    ...
# 133      LOA       DEFESA  52903
# 134      LOA  AERONAUTICA  52911
# 135      LOA     EXERCITO  52921
# 136      LOA      MARINHA  52931
# 137      LOA      MARINHA  52932
#
#                                     ORGAO ORCAMENTARIO  \
# 0                                 Ministerio da Defesa
# 1          Ministerio da Defesa - Administracao Direta
# 2                               Comando da Aeronautica
# 3                                  Comando do Exercito
# 4                                   Comando da Marinha
# ..                                                 ...
# 133                           Fundo do Servico Militar
# 134                                  Fundo Aeronautico
# 135                                  Fundo do Exercito
# 136                                        Fundo Naval
# 137  Fundo de Desenvolvimento do Ensino Profissiona...
#
#                                                 TITULO  \
# 0    Receitas de Todas as Fontes por Orgao e Unidad...
# 1    Receitas de Todas as Fontes por Orgao e Unidad...
# 2    Receitas de Todas as Fontes por Órgão e Unidad...
# 3    Receitas de Todas as Fontes por Órgão e Unidad...
# 4    Receitas de Todas as Fontes por Órgão e Unidad...
# ..                                                 ...
# 133  Receitas de Todas as Fontes por Orgao e Unidad...
# 134  Receitas de Todas as Fontes por Órgão e Unidad...
# 135  Receitas de Todas as Fontes por Órgão e Unidad...
# 136  Receitas de Todas as Fontes por Órgão e Unidad...
# 137  Receitas de Todas as Fontes por Órgão e Unidad...
#
#                                                  FONTE  EXERCICIO FINANCEIRO  \
# 0    Orcamento da Uniao – Exercicio financeiro de 2...                  2023
# 1    Orcamento da Uniao – Exercicio financeiro de 2...                  2023
# 2    Orçamento da União – Exercício financeiro de 2...                  2023
# 3    Orçamento da União – Exercício financeiro de 2...                  2023
# 4    Orçamento da União – Exercício financeiro de 2...                  2023
# ..                                                 ...                   ...
# 133  Orcamento da Uniao – Exercicio financeiro de 2...                  2016
# 134  Orçamento da União – Exercício financeiro de 2...                  2016
# 135  Orçamento da União – Exercício financeiro de 2...                  2016
# 136  Orçamento da União – Exercício financeiro de 2...                  2016
# 137  Orçamento da União – Exercício financeiro de 2...                  2016
#
#            VALOR
# 0    23705992174
# 1     8736247276
# 2     1208795261
# 3       51504959
# 4     2771674289
# ..           ...
# 133      7132056
# 134   2568966238
# 135   1207720536
# 136    731487183
# 137    226438475
#
# [138 rows x 8 columns]

# %%
#!pip install memory_profiler

# %%
from memory_profiler import profile

@profile
def load_and_process_data(filepath):
    df_teste_desempenho = pd.read_csv(filepath)
    # Realize algumas operações de data wrangling com pandas
    df_teste_desempenho = df_teste_desempenho.dropna()  # Exemplo de operação
    return df

# Chame a função com o caminho do seu arquivo CSV
load_and_process_data('Receitas Un.Orcam MD AnexoI (1).csv')

# %%
from memory_profiler import memory_usage

def test_pandas_memory_usage():
    df = pd.read_csv("Receitas_Un.Orcam_MD_AnexoI.csv")
    result = df.groupby('ORGAO ORCAMENTARIO')['VALOR'].sum()
    
#if __name__ == '__main__':
#    mem_usage = memory_usage((test_pandas_memory_usage, ))
#    print(f"Pico de uso de memória: {max(mem_usage)} MiB")

# Medir memória antes da execução
mem_before = memory_usage(-1, interval=1, timeout=1)

# Executar a função
test_pandas_memory_usage()

# Medir memória depois da execução
mem_after = memory_usage(-1, interval=1, timeout=1)

# Calcular a diferença
mem_increase = mem_after[0] - mem_before[0]
print(f"Aumento de uso de memória: {mem_increase} MiB")
# Out:
# Aumento de uso de memória: 9.9609375 MiB

# %%
#Entendimento do Dataset e obtenção de informações gerais
f_receita_orc_md.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138 entries, 0 to 137
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   SKU REF.              138 non-null    object
#  1   FA                    138 non-null    object
#  2   SKU                   138 non-null    int64
#  3   ORGAO ORCAMENTARIO    138 non-null    object
#  4   TITULO                138 non-null    object
#  5   FONTE                 138 non-null    object
#  6   EXERCICIO FINANCEIRO  138 non-null    int64
#  7   VALOR                 138 non-null    int64
# dtypes: int64(3), object(5)
# memory usage: 8.8+ KB

# %%
df_describe = f_receita_orc_md.describe()

# %%
import matplotlib.pyplot as plt
from pandas.plotting import table

fig, ax = plt.subplots(figsize=(8, 3))
ax.axis('off')
the_table = table(ax, df_describe, loc='center', cellLoc='center')    
plt.tight_layout()
plt.show()

# %%
# gráfico de boxplot para análise da dispersão do dados da coluna valor
boxplot = f_receita_orc_md.boxplot(column=['VALOR'], showmeans=True)

# %%
f_receita_orc_md['VALOR'].plot(kind='hist', bins=20)
plt.xlabel('Valor')
#plt.ticklabel_format(style='plain', axis='x')
plt.ylabel('Frequência')
#plt.title('Distribuição dos Valores Financeiros')
plt.show()

# %%
import seaborn as sns
# 1. Agrupar por 'ORGAO ORCAMENTARIO' e somar os 'VALOR'
top7_orgaos = f_receita_orc_md.groupby('ORGAO ORCAMENTARIO')['VALOR'].sum().reset_index()

# 2. Ordenar os resultados e selecionar os top 7
top7_orgaos = top7_orgaos.sort_values(by='VALOR', ascending=False).head(7)

# 3. Criar um gráfico de barras
plt.figure(figsize=(10, 6))
sns.barplot(x='VALOR', y='ORGAO ORCAMENTARIO', data=top7_orgaos)
#plt.title('Top 7 Órgãos Orçamentários por Valor Total')
plt.xlabel('Valor Total Orçamentário')
plt.ylabel('Órgão Orçamentário')
plt.yticks(rotation=30)  # Rotação dos rótulos do eixo y, se necessário
plt.show()

# %%
top7_orgaos.groupby('ORGAO ORCAMENTARIO')['VALOR'].sum().plot(kind='bar', rot=50, figsize=(15, 6), fontsize=8)
# Out:
# <Axes: xlabel='ORGAO ORCAMENTARIO'>

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=f_receita_orc_md, x='EXERCICIO FINANCEIRO', y='VALOR', hue='FA', marker='o')
#plt.title('Tendência de Valores Orçamentários por Ano e Força Armada')
plt.xlabel('Exercício Financeiro')
plt.ylabel('Valor')
plt.show()

# %%
# Gráfico de Dispersão
plt.figure(figsize=(10, 6))
sns.scatterplot(data=f_receita_orc_md, x='SKU', y='VALOR', hue='FA')
#plt.title('Relação entre SKU e Valor Orçamentário')
plt.xlabel('SKU')
plt.ylabel('Valor')
plt.show()

# %%
# Criando o resumo do DataFrame
df_sum = f_receita_orc_md.groupby('FA')['VALOR'].sum().reset_index()

# Gráfico de pizza
plt.figure(figsize=(8, 8))
plt.pie(df_sum['VALOR'], labels=df_sum['FA'], autopct='%1.1f%%', startangle=140)
#plt.title('Proporção Orçamentária por Força Armada')
plt.show()

# %%
# Suponha que df_receita_orcamento_md seja o seu DataFrame
# df_receita_orcamento_md = ...

# Gráfico de Barra
f_receita_orc_md.groupby('FA')['VALOR'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='FA'>

# %%
# Gráfico de Linha
f_receita_orc_md.groupby('EXERCICIO FINANCEIRO')['VALOR'].sum().plot(kind='line')
# Out:
# <Axes: xlabel='EXERCICIO FINANCEIRO'>

# %%
# Gráfico de Dispersão
f_receita_orc_md.plot(kind='scatter', x='SKU', y='VALOR')
# Out:
# <Axes: xlabel='SKU', ylabel='VALOR'>

# %%
f_receita_orc_md.groupby('FA')['VALOR'].sum().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='VALOR'>

# %%
# Obtendo valores únicos de uma coluna
f_receita_orc_md['ORGAO ORCAMENTARIO'].unique()
f_receita_orc_md['TITULO'].unique()
# Out:
# array(['Receitas de Todas as Fontes por Orgao e Unidade Orcamentaria',
#        'Receitas de Todas as Fontes por Órgão e Unidade Orçamentária'],
#       dtype=object)

# %%
# Renomeando as colunas
format_receita_md = f_receita_orc_md.rename(columns={
    'SKU': 'Codigo',
    'VALOR': 'Receita'
})
# Convertendo a coluna 'Codigo' para string
format_receita_md['Codigo'] = format_receita_md['Codigo'].astype(str)

# formatação da coluna FONTE para resumo das informações
# Definindo uma função para aplicar a lógica de case_when
def redefinir_fonte(fonte):
    if "LDO-2023" in fonte:
        return "LDO-2023"
    elif "LDO-2022" in fonte:
        return "LDO-2022"
    elif "LDO-2021" in fonte:
        return "LDO-2021"
    elif "LDO-2020" in fonte:
        return "LDO-2020"
    elif "LDO-2019" in fonte:
        return "LDO-2019"
    elif "LDO-2018" in fonte:
        return "LDO-2018"
    elif "LDO-2017" in fonte:
        return "LDO-2017"
    elif "LDO-2016" in fonte:
        return "LDO-2016"
    else:
        return fonte

# Aplicando a função ao DataFrame
format_receita_md['FONTE'] = format_receita_md['FONTE'].apply(redefinir_fonte)

format_receita_md.drop(columns=['SKU REF.', 'TITULO'], inplace=True)

# %%
# Aplicando estilo ao DataFrame
styled_df = format_receita_md.style.set_table_attributes('class="table table-striped"').set_properties(**{'font-size': '10pt'})

# Exibindo o DataFrame estilizado
styled_df
# Out:
# <style type="text/css">
# #T_18825_row0_col0, #T_18825_row0_col1, #T_18825_row0_col2, #T_18825_row0_col3, #T_18825_row0_col4, #T_18825_row0_col5, #T_18825_row1_col0, #T_18825_row1_col1, #T_18825_row1_col2, #T_18825_row1_col3, #T_18825_row1_col4, #T_18825_row1_col5, #T_18825_row2_col0, #T_18825_row2_col1, #T_18825_row2_col2, #T_18825_row2_col3, #T_18825_row2_col4, #T_18825_row2_col5, #T_18825_row3_col0, #T_18825_row3_col1, #T_18825_row3_col2, #T_18825_row3_col3, #T_18825_row3_col4, #T_18825_row3_col5, #T_18825_row4_col0, #T_18825_row4_col1, #T_18825_row4_col2, #T_18825_row4_col3, #T_18825_row4_col4, #T_18825_row4_col5, #T_18825_row5_col0, #T_18825_row5_col1, #T_18825_row5_col2, #T_18825_row5_col3, #T_18825_row5_col4, #T_18825_row5_col5, #T_18825_row6_col0, #T_18825_row6_col1, #T_18825_row6_col2, #T_18825_row6_col3, #T_18825_row6_col4, #T_18825_row6_col5, #T_18825_row7_col0, #T_18825_row7_col1, #T_18825_row7_col2, #T_18825_row7_col3, #T_18825_row7_col4, #T_18825_row7_col5, #T_18825_row8_col0, #T_18825_row8_col1, #T_18825_row8_col2, #T_18825_row8_col3, #T_18825_row8_col4, #T_18825_row8_col5, #T_18825_row9_col0, #T_18825_row9_col1, #T_18825_row9_col2, #T_18825_row9_col3, #T_18825_row9_col4, #T_18825_row9_col5, #T_18825_row10_col0, #T_18825_row10_col1, #T_18825_row10_col2, #T_18825_row10_col3, #T_18825_row10_col4, #T_18825_row10_col5, #T_18825_row11_col0, #T_18825_row11_col1, #T_18825_row11_col2, #T_18825_row11_col3, #T_18825_row11_col4, #T_18825_row11_col5, #T_18825_row12_col0, #T_18825_row12_col1, #T_18825_row12_col2, #T_18825_row12_col3, #T_18825_row12_col4, #T_18825_row12_col5, #T_18825_row13_col0, #T_18825_row13_col1, #T_18825_row13_col2, #T_18825_row13_col3, #T_18825_row13_col4, #T_18825_row13_col5, #T_18825_row14_col0, #T_18825_row14_col1, #T_18825_row14_col2, #T_18825_row14_col3, #T_18825_row14_col4, #T_18825_row14_col5, #T_18825_row15_col0, #T_18825_row15_col1, #T_18825_row15_col2, #T_18825_row15_col3, #T_18825_row15_col4, #T_18825_row15_col5, #T_18825_row16_col0, #T_18825_row16_col1, #T_18825_row16_col2, #T_18825_row16_col3, #T_18825_row16_col4, #T_18825_row16_col5, #T_18825_row17_col0, #T_18825_row17_col1, #T_18825_row17_col2, #T_18825_row17_col3, #T_18825_row17_col4, #T_18825_row17_col5, #T_18825_row18_col0, #T_18825_row18_col1, #T_18825_row18_col2, #T_18825_row18_col3, #T_18825_row18_col4, #T_18825_row18_col5, #T_18825_row19_col0, #T_18825_row19_col1, #T_18825_row19_col2, #T_18825_row19_col3, #T_18825_row19_col4, #T_18825_row19_col5, #T_18825_row20_col0, #T_18825_row20_col1, #T_18825_row20_col2, #T_18825_row20_col3, #T_18825_row20_col4, #T_18825_row20_col5, #T_18825_row21_col0, #T_18825_row21_col1, #T_18825_row21_col2, #T_18825_row21_col3, #T_18825_row21_col4, #T_18825_row21_col5, #T_18825_row22_col0, #T_18825_row22_col1, #T_18825_row22_col2, #T_18825_row22_col3, #T_18825_row22_col4, #T_18825_row22_col5, #T_18825_row23_col0, #T_18825_row23_col1, #T_18825_row23_col2, #T_18825_row23_col3, #T_18825_row23_col4, #T_18825_row23_col5, #T_18825_row24_col0, #T_18825_row24_col1, #T_18825_row24_col2, #T_18825_row24_col3, #T_18825_row24_col4, #T_18825_row24_col5, #T_18825_row25_col0, #T_18825_row25_col1, #T_18825_row25_col2, #T_18825_row25_col3, #T_18825_row25_col4, #T_18825_row25_col5, #T_18825_row26_col0, #T_18825_row26_col1, #T_18825_row26_col2, #T_18825_row26_col3, #T_18825_row26_col4, #T_18825_row26_col5, #T_18825_row27_col0, #T_18825_row27_col1, #T_18825_row27_col2, #T_18825_row27_col3, #T_18825_row27_col4, #T_18825_row27_col5, #T_18825_row28_col0, #T_18825_row28_col1, #T_18825_row28_col2, #T_18825_row28_col3, #T_18825_row28_col4, #T_18825_row28_col5, #T_18825_row29_col0, #T_18825_row29_col1, #T_18825_row29_col2, #T_18825_row29_col3, #T_18825_row29_col4, #T_18825_row29_col5, #T_18825_row30_col0, #T_18825_row30_col1, #T_18825_row30_col2, #T_18825_row30_col3, #T_18825_row30_col4, #T_18825_row30_col5, #T_18825_row31_col0, #T_18825_row31_col1, #T_18825_row31_col2, #T_18825_row31_col3, #T_18825_row31_col4, #T_18825_row31_col5, #T_18825_row32_col0, #T_1882 ...

# %%
# Configurando o Pandas para exibir números sem notação científica
pd.set_option('display.float_format', lambda x: '%.3f' % x)

#-> para reverter a configuração para voltar a utlizar notação científica. 
#pd.reset_option('display.float_format')

# %%
# Agrupando por 'FA' e calculando as estatísticas desejadas
desc_FA_Receita = format_receita_md.groupby('FA').agg(
    observações=('Receita', 'count'),
    média=('Receita', 'mean'),
    mediana=('Receita', 'median'),
    soma=('Receita', 'sum'),
    maximo=('Receita', 'max'),
    minimo=('Receita', 'min')
).sort_values(by='maximo', ascending=False)

# Exibindo o resultado
#print(desc_FA_Receita)
# Criando a figura
fig, ax = plt.subplots(figsize=(10, 2))  # Ajuste o tamanho conforme necessário
ax.axis('off')  # Desativa os eixos

# Adicionando a tabela
tab = table(ax, desc_FA_Receita, loc='center', cellLoc='center')
# Ajustando o estilo da tabela, se necessário
tab.auto_set_font_size(False)
tab.set_fontsize(10)
tab.scale(1.2, 1.2)  # Ajuste o tamanho conforme necessário

# Salvando a figura
plt.savefig('tabela.png')

# Exibindo a figura
plt.show()

# %%
# Filtrando o DataFrame
filtered_df = format_receita_md.groupby('FA').apply(
    lambda x: x[(x['EXERCICIO FINANCEIRO'] >= 2022) & (x['Receita'] > 483513773)]
).reset_index(drop=True)

filtered_df
# Out:
#              FA Codigo                               ORGAO ORCAMENTARIO  \
# 0   AERONAUTICA  52111                           Comando da Aeronautica
# 1   AERONAUTICA  52911                                Fundo Aeronautico
# 2   AERONAUTICA  52111                           Comando da Aeronautica
# 3   AERONAUTICA  52911                                Fundo Aeronautico
# 4        DEFESA  52000                             Ministerio da Defesa
# 5        DEFESA  52101      Ministerio da Defesa - Administracao Direta
# 6        DEFESA  52000                             Ministerio da Defesa
# 7        DEFESA  52101      Ministerio da Defesa - Administracao Direta
# 8      EXERCITO  52921                                Fundo do Exercito
# 9      EXERCITO  52921                                Fundo do Exercito
# 10      MARINHA  52131                               Comando da Marinha
# 11      MARINHA  52231  Empresa Gerencial de Projetos Navais - EMGEPRON
# 12      MARINHA  52931                                      Fundo Naval
# 13      MARINHA  52131                               Comando da Marinha
# 14      MARINHA  52931                                      Fundo Naval
#
#        FONTE  EXERCICIO FINANCEIRO      Receita
# 0   LDO-2023                  2023   1208795261
# 1   LDO-2023                  2023   3417612683
# 2   LDO-2022                  2022   1196820839
# 3   LDO-2022                  2022   3353711878
# 4   LDO-2023                  2023  23705992174
# 5   LDO-2023                  2023   8736247276
# 6   LDO-2022                  2022  18535782538
# 7   LDO-2022                  2022   8593872028
# 8   LDO-2023                  2023   2266770610
# 9   LDO-2022                  2022   1945889227
# 10  LDO-2023                  2023   2771674289
# 11  LDO-2023                  2023   3239426689
# 12  LDO-2023                  2023   1394912809
# 13  LDO-2022                  2022   1930439944
# 14  LDO-2022                  2022   1066411236

# %%
num_rows = len(format_receita_md)
top_10_percent = int(num_rows * 0.10)  # Calculando 10% do número total de linhas

# Ordenando por 'Receita' e pegando as top 10%
top_receitas = format_receita_md.sort_values(by='Receita', ascending=False).iloc[:top_10_percent]

#top_receitas.head(10)

# %%
# Ordenando por 'Receita' e pegando as bottom 10%
bottom_receitas = format_receita_md.sort_values(by='Receita', ascending=True).iloc[:top_10_percent]
bottom_receitas.head(10)
# Out:
#           FA Codigo                                 ORGAO ORCAMENTARIO  \
# 17   MARINHA  52233  Amazonia Azul Tecnologias de Defesa S.A. - AMAZUL
# 26   MARINHA  52231    Empresa Gerencial de Projetos Navais - EMGEPRON
# 35   MARINHA  52233  Amazonia Azul Tecnologias de Defesa S.A. - AMAZUL
# 52   MARINHA  52233  Amazonia Azul Tecnologias de Defesa S.A. - AMAZUL
# 86   MARINHA  52233  Amazonia Azul Tecnologias de Defesa S.A. - AMAZUL
# 69   MARINHA  52233  Amazonia Azul Tecnologias de Defesa S.A. - AMAZUL
# 46    DEFESA  52902  Fundo de Administracao do Hospital das Forcas ...
# 77  EXERCITO  52222                                    Fundacao Osorio
# 43  EXERCITO  52222                                    Fundacao Osorio
# 7   EXERCITO  52222                                    Fundacao Osorio
#
#        FONTE  EXERCICIO FINANCEIRO  Receita
# 17  LDO-2023                  2023        0
# 26  LDO-2022                  2022        0
# 35  LDO-2022                  2022        0
# 52  LDO-2021                  2021        0
# 86  LDO-2019                  2019        0
# 69  LDO-2020                  2020        0
# 46  LDO-2021                  2021     2594
# 77  LDO-2019                  2019   136793
# 43  LDO-2021                  2021   200451
# 7   LDO-2023                  2023   377006

# %%
# importação e formatação da tabela de despesa orçamento MD
f_despesa_md = pd.read_csv(r"Despesa_por_Un._TipoI.csv")

format_despesa_md = f_despesa_md.rename(columns={
    'SKU': 'Codigo',
    'TOTAL': 'Despesa',
    'TOTAL 2-9': 'Despesa 2-9' 
})
# Convertendo a coluna 'Codigo' para string
format_despesa_md['Codigo'] = format_despesa_md['Codigo'].astype(str)
#Excluindo as colunas que não serão utilizadas
format_despesa_md.drop(columns=['SKU REF.', 'FA', 'ORGAO ORCAMENTARIO', 'TITULO', 'FONTE'], inplace=True)
format_despesa_md.head(3)
# Out:
#   Codigo  EXERCICIO FINANCEIRO  1-Pessoal e Encargos Sociais  \
# 0  52101                  2023                     178366694
# 1  52111                  2023                   21541524168
# 2  52121                  2023                   47100748292
#
#    2-Juros e Encargos da Divida  3-Outras Despesas Correntes  4-Investimentos  \
# 0                             0                   1116216767       1529795730
# 1                     783658286                   1169361566       1947271833
# 2                             0                   3873631933       1840375304
#
#    5-Inversoes Financeiras  6-Amortizacao da Divida  \
# 0                        0                        0
# 1                        0                663194004
# 2                        0                        0
#
#    7-Reserva de Regime Proprio da Previdencia Social RPPS  8-N/A  \
# 0                                                  0           0
# 1                                                  0           0
# 2                                                  0           0
#
#    9-Reserva de Contingencia      Despesa  Despesa 2-9
# 0                          0   2824379191   5470391688
# 1                          0  26105009857  30668495546
# 2                   40060000  52854815529  58608882766

# %%
#md_receita_despesa <- left_join(format_receita_md, format_despesa_md, by = c("Codigo", "EXERCICIO FINANCEIRO"))
md_receita_despesa = pd.merge(format_receita_md, format_despesa_md, on=['Codigo', 'EXERCICIO FINANCEIRO'], how='left')
#md_receita_despesa.head(3)

# %%
vetor_variaveis_selecionadas = ["Receita", "Despesa", "Despesa 2-9"]

# Aplicar a função describe em cada coluna selecionada após remover NA
estatisticas_orcamento = {coluna: md_receita_despesa[coluna].dropna().describe() for coluna in vetor_variaveis_selecionadas}

# Para ver o resultado
print(estatisticas_orcamento)
# Out:
# {'Receita': count           138.000
# mean     1757348714.094
# std      3850179699.663
# min               0.000
# 25%        10857691.250
# 50%       107421567.500
# 75%      1656025825.250
# max     23705992174.000
# Name: Receita, dtype: float64, 'Despesa': count           130.000
# mean     5865919710.192
# std     11658838536.758
# min               0.000
# 25%        26650962.750
# 50%       273069605.000
# 75%      3127577764.000
# max     52854815529.000
# Name: Despesa, dtype: float64, 'Despesa 2-9': count           130.000
# mean     7404531835.977
# std     13477713592.449
# min               0.000
# 25%        37211799.000
# 50%       395674567.500
# 75%      6219206721.500
# max     58608882766.000
# Name: Despesa 2-9, dtype: float64}

# %%
vetor_variaveis_selecionadas = ["Receita", "Despesa", "Despesa 2-9"]

# Função para formatar a saída similar ao summary do R
def summary_like(df, col):
    stats = df[col].dropna().describe(percentiles=[.25, .5, .75])
    stats = stats.rename(index={'25%': '1st Qu.', '50%': 'Median', '75%': '3rd Qu.'})
    return stats.loc[['min', '1st Qu.', 'Median', 'mean', '3rd Qu.', 'max']]

# Aplicando a função para cada coluna e armazenando os resultados
estatisticas_orcamento = {coluna: summary_like(md_receita_despesa, coluna) for coluna in vetor_variaveis_selecionadas}

# Para ver o resultado
for coluna, stats in estatisticas_orcamento.items():
    print(f"{coluna}:\n{stats}\n")
# Out:
# Receita:
# min                 0.000
# 1st Qu.      10857691.250
# Median      107421567.500
# mean       1757348714.094
# 3rd Qu.    1656025825.250
# max       23705992174.000
# Name: Receita, dtype: float64
#
# Despesa:
# min                 0.000
# 1st Qu.      26650962.750
# Median      273069605.000
# mean       5865919710.192
# 3rd Qu.    3127577764.000
# max       52854815529.000
# Name: Despesa, dtype: float64
#
# Despesa 2-9:
# min                 0.000
# 1st Qu.      37211799.000
# Median      395674567.500
# mean       7404531835.977
# 3rd Qu.    6219206721.500
# max       58608882766.000
# Name: Despesa 2-9, dtype: float64

# %%
# Calculando a quantidade de valores NA em cada coluna
qtd_na = md_receita_despesa.isna().sum()
# Exibindo o resultado
#print(qtd_na)

# Filtrando linhas que contêm pelo menos um valor NA
linhas_na = md_receita_despesa[md_receita_despesa.isna().any(axis=1)]
#print(linhas_na)

# Filtrando linhas onde todas as colunas têm o valor ""
linhas_vazias = md_receita_despesa[(md_receita_despesa == "").all(axis=1)]
#print(linhas_vazias)

# Filtrando para manter apenas linhas completas (sem valores NA)
md_receita_despesa = md_receita_despesa.dropna()

#md_receita_despesa.drop(columns=['8-N/A', '9-Reserva de Contingencia'], inplace=True)

print(md_receita_despesa)
# Out:
#               FA Codigo                                 ORGAO ORCAMENTARIO  \
# 1         DEFESA  52101        Ministerio da Defesa - Administracao Direta
# 2    AERONAUTICA  52111                             Comando da Aeronautica
# 3       EXERCITO  52121                                Comando do Exercito
# 4        MARINHA  52131                                 Comando da Marinha
# 5    AERONAUTICA  52211  Caixa de Financiamento Imobiliario da Aeronautica
# ..           ...    ...                                                ...
# 133       DEFESA  52903                           Fundo do Servico Militar
# 134  AERONAUTICA  52911                                  Fundo Aeronautico
# 135     EXERCITO  52921                                  Fundo do Exercito
# 136      MARINHA  52931                                        Fundo Naval
# 137      MARINHA  52932  Fundo de Desenvolvimento do Ensino Profissiona...
#
#         FONTE  EXERCICIO FINANCEIRO     Receita  1-Pessoal e Encargos Sociais  \
# 1    LDO-2023                  2023  8736247276                 178366694.000
# 2    LDO-2023                  2023  1208795261               21541524168.000
# 3    LDO-2023                  2023    51504959               47100748292.000
# 4    LDO-2023                  2023  2771674289               25133032781.000
# 5    LDO-2023                  2023    13022428                   1564551.000
# ..        ...                   ...         ...                           ...
# 133  LDO-2016                  2016     7132056                         0.000
# 134  LDO-2016                  2016  2568966238                         0.000
# 135  LDO-2016                  2016  1207720536                         0.000
# 136  LDO-2016                  2016   731487183                         0.000
# 137  LDO-2016                  2016   226438475                         0.000
#
#      2-Juros e Encargos da Divida  3-Outras Despesas Correntes  \
# 1                           0.000               1116216767.000
# 2                   783658286.000               1169361566.000
# 3                           0.000               3873631933.000
# 4                   368019077.000               1754587645.000
# 5                           0.000                  2165608.000
# ..                            ...                          ...
# 133                         0.000                  5681784.000
# 134                         0.000               1498164537.000
# 135                         0.000               1052052085.000
# 136                         0.000                623715447.000
# 137                         0.000                 74552083.000
#
#      4-Investimentos  5-Inversoes Financeiras  6-Amortizacao da Divida  \
# 1     1529795730.000                    0.000                    0.000
# 2     1947271833.000                    0.000            663194004.000
# 3     1840375304.000                    0.000                    0.000
# 4     2014224441.000                    0.000           1236564332.000
# 5         170000.000                    0.000                    0.000
# ..               ...                      ...                      ...
# 133      1450272.000                    0.000                    0.000
# 134   1059144761.000              4850000.000                    0.000
# 135     51910673.000                    0.000                    0.000
# 136     56055226.000                    0.000                    0.000
# 137      6861593.000                    0.000                    0.000
#
#      7-Reserva de Regime Proprio da Previdencia Social RPPS  8-N/A  \
# 1                                                0.000       0.000
# 2                                                0.000       0.000
# 3                                                0.000       0.000
# 4                                                0.000       0.000
# 5                                                0.000       0.000
# ..                                                 ...         ...
# 133                                              0.000       0.000
# 134                                              0.000       0.000
# 135                                              0.000       0.000
# 136                                              0.000       0.000
# 137                                              0.000       0.000
#
#      9-Reserva de Contingencia         Despesa     Despesa 2-9
# 1                        0.000  2824379191.000  5470391688.000
# 2                        0.000 26105009857.000 30668495546.000
# 3                 40060000.000 52854815529.000 58608882766.000
# 4                875261835.000 31381690111.000 37630347441.000
# 5                  9293011.000    13193170.000    24821789.000
# ..                         ...             ...             ...
# 133                      0.000     7132056.000    14264112.000
# 134                6806940.000  2568966238.000  5137932476.000
# 135              106359246.000  1210322004.000  2420644008.000
# 136               52293095.000   732063768.000  1464127536.000
# 137              138369441.000   219783117.000   439566234.000
#
# [130 rows x 17 columns]

# %%
# Calculando a proporção de 'Receita' e 'Despesa'
proporcao_receita = md_receita_despesa['Receita'] / md_receita_despesa['Receita'].sum()
proporcao_despesa = md_receita_despesa['Despesa'] / md_receita_despesa['Despesa'].sum()

# Definindo os rótulos das categorias
labels = ["muito baixo", "baixo", "médio", "alto", "muito alto"]

# Categorizando 'Receita'
md_receita_despesa['Categoria Receita'] = pd.qcut(proporcao_receita, 
                                                  q=[0, .2, .4, .6, .8, 1],
                                                  labels=labels)

# Categorizando 'Despesa'
md_receita_despesa['Categoria Despesa'] = pd.qcut(proporcao_despesa, 
                                                  q=[0, .2, .4, .6, .8, 1],
                                                  labels=labels)

# Exibindo o DataFrame enriquecido
display(md_receita_despesa)
# Out:
#               FA Codigo                                 ORGAO ORCAMENTARIO  \
# 1         DEFESA  52101        Ministerio da Defesa - Administracao Direta
# 2    AERONAUTICA  52111                             Comando da Aeronautica
# 3       EXERCITO  52121                                Comando do Exercito
# 4        MARINHA  52131                                 Comando da Marinha
# 5    AERONAUTICA  52211  Caixa de Financiamento Imobiliario da Aeronautica
# ..           ...    ...                                                ...
# 133       DEFESA  52903                           Fundo do Servico Militar
# 134  AERONAUTICA  52911                                  Fundo Aeronautico
# 135     EXERCITO  52921                                  Fundo do Exercito
# 136      MARINHA  52931                                        Fundo Naval
# 137      MARINHA  52932  Fundo de Desenvolvimento do Ensino Profissiona...
#
#         FONTE  EXERCICIO FINANCEIRO     Receita  1-Pessoal e Encargos Sociais  \
# 1    LDO-2023                  2023  8736247276                 178366694.000
# 2    LDO-2023                  2023  1208795261               21541524168.000
# 3    LDO-2023                  2023    51504959               47100748292.000
# 4    LDO-2023                  2023  2771674289               25133032781.000
# 5    LDO-2023                  2023    13022428                   1564551.000
# ..        ...                   ...         ...                           ...
# 133  LDO-2016                  2016     7132056                         0.000
# 134  LDO-2016                  2016  2568966238                         0.000
# 135  LDO-2016                  2016  1207720536                         0.000
# 136  LDO-2016                  2016   731487183                         0.000
# 137  LDO-2016                  2016   226438475                         0.000
#
#      2-Juros e Encargos da Divida  3-Outras Despesas Correntes  \
# 1                           0.000               1116216767.000
# 2                   783658286.000               1169361566.000
# 3                           0.000               3873631933.000
# 4                   368019077.000               1754587645.000
# 5                           0.000                  2165608.000
# ..                            ...                          ...
# 133                         0.000                  5681784.000
# 134                         0.000               1498164537.000
# 135                         0.000               1052052085.000
# 136                         0.000                623715447.000
# 137                         0.000                 74552083.000
#
#      4-Investimentos  5-Inversoes Financeiras  6-Amortizacao da Divida  \
# 1     1529795730.000                    0.000                    0.000
# 2     1947271833.000                    0.000            663194004.000
# 3     1840375304.000                    0.000                    0.000
# 4     2014224441.000                    0.000           1236564332.000
# 5         170000.000                    0.000                    0.000
# ..               ...                      ...                      ...
# 133      1450272.000                    0.000                    0.000
# 134   1059144761.000              4850000.000                    0.000
# 135     51910673.000                    0.000                    0.000
# 136     56055226.000                    0.000                    0.000
# 137      6861593.000                    0.000                    0.000
#
#      7-Reserva de Regime Proprio da Previdencia Social RPPS  8-N/A  \
# 1                                                0.000       0.000
# 2                                                0.000       0.000
# 3                                                0.000       0.000
# 4                                                0.000       0.000
# 5                                                0.000       0.000
# ..                                                 ...         ...
# 133                                              0.000       0.000
# 134                                              0.000       0.000
# 135                                              0.000       0.000
# 136                                              0.000       0.000
# 137                                              0.000       0.000
#
#      9-Reserva de Contingencia         Despesa     Despesa 2-9  \
# 1                        0.000  2824379191.000  5470391688.000
# 2                        0.000 26105009857.000 30668495546.000
# 3                 40060000.000 52854815529.000 58608882766.000
# 4                875261835.000 31381690111.000 37630347441.000
# 5                  9293011.000    13193170.000    24821789.000
# ..                         ...             ...             ...
# 133                      0.000     7132056.000    14264112.000
# 134                6806940.000  2568966238.000  5137932476.000
# 135              106359246.000  1210322004.000  2420644008.000
# 136               52293095.000   732063768.000  1464127536.000
# 137              138369441.000   219783117.000   439566234.000
#
#     Categoria Receita Categoria Despesa
# 1          muito alto              alto
# 2                alto        muito alto
# 3               médio        muito alto
# 4          muito alto        muito alto
# 5               baixo       muito baixo
# ..                ...               ...
# 133             baixo       muito baixo
# 134        muito alto              alto
# 135              alto              alto
# 136              alto             médio
# 137             médio             baixo
#
# [130 rows x 19 columns]

# %%
# Salvando format_df__receita_md como um arquivo CSV
format_receita_md.to_csv("df_receita_md.csv", index=False)

# Salvando f_despesa_md como um arquivo CSV
format_despesa_md.to_csv("df_despesa_md.csv", index=False)

# Salvando md_receita_despesa como um arquivo CSV
md_receita_despesa.to_csv("orcamento_md.csv", index=False)
